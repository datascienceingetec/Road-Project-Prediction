# %%
import pandas as pd
import os
import sys
import warnings

warnings.filterwarnings('ignore')

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.insert(0, project_root)

from app.services import ModelsManagement
from app.utils import ml_utils

from app.services.models_management import train_brindges_structures_model
from app.utils.ml_utils import get_bridges_structures_tunnels


# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
fase='III'
mm = ModelsManagement(fase)
df_vp = mm.prepare_data()
results, summary_df = mm.train_models()
summary_df
# Out:
#                                Target                    Alcance  \
# 0        2.1 - INFORMACIÓN GEOGRÁFICA            Segunda calzada
# 1        2.1 - INFORMACIÓN GEOGRÁFICA  operacion y mantenimiento
# 2        2.1 - INFORMACIÓN GEOGRÁFICA             Rehabilitación
# 3   2.2 - TRAZADO Y DISEÑO GEOMÉTRICO            Segunda calzada
# 4   2.2 - TRAZADO Y DISEÑO GEOMÉTRICO  operacion y mantenimiento
# 5   2.2 - TRAZADO Y DISEÑO GEOMÉTRICO               Mejoramiento
# 6   2.2 - TRAZADO Y DISEÑO GEOMÉTRICO             Rehabilitación
# 7   2.2 - TRAZADO Y DISEÑO GEOMÉTRICO             Puesta a punto
# 8                2.3 - SEGURIDAD VIAL            Segunda calzada
# 9                2.3 - SEGURIDAD VIAL  operacion y mantenimiento
# 10               2.3 - SEGURIDAD VIAL               Mejoramiento
# 11               2.3 - SEGURIDAD VIAL             Rehabilitación
# 12               2.3 - SEGURIDAD VIAL             Puesta a punto
# 13        2.4 - SISTEMAS INTELIGENTES            Segunda calzada
# 14        2.4 - SISTEMAS INTELIGENTES  operacion y mantenimiento
# 15        2.4 - SISTEMAS INTELIGENTES               Mejoramiento
# 16        2.4 - SISTEMAS INTELIGENTES             Puesta a punto
# 17                        5 - TALUDES            Segunda calzada
# 18                        5 - TALUDES               Mejoramiento
# 19                        5 - TALUDES             Rehabilitación
# 20                        5 - TALUDES             Puesta a punto
# 21                      6 - PAVIMENTO            Segunda calzada
# 22                      6 - PAVIMENTO             Rehabilitación
# 23                      6 - PAVIMENTO               Mejoramiento
# 24                      6 - PAVIMENTO             Puesta a punto
# 25                     7 - SOCAVACIÓN            Segunda calzada
# 26                     7 - SOCAVACIÓN  operacion y mantenimiento
# 27                     7 - SOCAVACIÓN               Mejoramiento
# 28                     7 - SOCAVACIÓN             Rehabilitación
# 29                     7 - SOCAVACIÓN             Puesta a punto
# 30                       11 - PREDIAL             Rehabilitación
# 31       15 - OTROS - MANEJO DE REDES            Segunda calzada
# 32       15 - OTROS - MANEJO DE REDES  operacion y mantenimiento
# 33       15 - OTROS - MANEJO DE REDES             Puesta a punto
# 34      16 - DIRECCIÓN Y COORDINACIÓN                    General
# 35                       3 - GEOLOGÍA                    General
# 36                         4 - SUELOS                    General
# 37                    8 - ESTRUCTURAS                    General
# 38                        9 - TÚNELES                    General
# 39        10 - URBANISMO Y PAISAJISMO                    General
# 40                    13 - CANTIDADES                    General
#
#                 Model     R²           MAE          RMSE  MAPE (%)  n_samples  \
# 0          ElasticNet  1.000  4.525410e+02  4.795720e+02     0.033          4
# 1          ElasticNet  1.000  3.358601e+03  3.565073e+03     0.163          3
# 2          ElasticNet  1.000  6.105030e+02  7.056370e+02     0.002          3
# 3                 SVR  0.492  9.999063e+05  1.874178e+06    29.641         16
# 4          ElasticNet  1.000  1.542748e+04  1.637573e+04     0.163          3
# 5               Ridge  0.338  4.954865e+06  9.490122e+06    36.907         10
# 6          ElasticNet  1.000  1.599611e+05  1.849783e+05     1.210          5
# 7          ElasticNet  1.000  1.080983e+04  1.358786e+04     0.169          8
# 8    Gaussian Process  0.864  8.529342e+05  1.734885e+06    25.556         17
# 9          ElasticNet  1.000  4.083710e+03  4.334749e+03     0.163          3
# 10              Ridge  0.083  4.392731e+06  7.039014e+06    59.423         10
# 11   Gaussian Process  0.900  1.427764e+06  3.036611e+06     4.501          5
# 12         ElasticNet  1.000  1.162009e+04  1.460636e+04     0.169          8
# 13     Bayesian Ridge  0.804  8.510775e+05  2.213944e+06     9.774         14
# 14         ElasticNet  1.000  1.701791e+04  1.806392e+04     0.163          3
# 15   Gaussian Process  1.000  2.098659e+04  5.837328e+04     0.068          8
# 16         ElasticNet  1.000  2.951602e+03  3.710140e+03     0.169          8
# 17              Ridge  0.999  3.781956e+04  6.636421e+04     0.698         12
# 18                SVR -0.259  7.964885e+06  1.377018e+07    56.895         11
# 19                SVR  0.374  1.128922e+07  2.051177e+07   117.532          5
# 20         ElasticNet  1.000  1.175027e+04  1.476999e+04     0.169          8
# 21              Ridge  1.000  1.174599e+03  1.407425e+03     0.050         11
# 22                SVR  0.671  5.683338e+06  1.164980e+07   147.217          5
# 23              Ridge -0.932  1.139075e+07  1.396147e+07   359.676          3
# 24         ElasticNet  1.000  5.246661e+03  6.595009e+03     0.169          8
# 25                SVR  0.411  6.089411e+06  8.521560e+06    40.552         18
# 26         ElasticNet  1.000  3.126238e+04  3.318388e+04     0.163          3
# 27              Ridge  0.688  5.254128e+06  8.647980e+06    34.804         10
# 28         ElasticNet  0.673  9.775898e+06  1.219700e+07    34.051          5
# 29         ElasticNet  1.000  2.454416e+04  3.085180e+04     0.169          8
# 30         ElasticNet  1.000  2.654530e+02  3.068190e+02     0.002          3
# 31                SVR  0.432  1.415328e+06  2.856360e+06    19.236         15
# 32         ElasticNet  1.000  1.720637e+04  1.826396e+04     0.163          3
# 33         ElasticNet  1.000  1.667318e+04  2.095804e+04     0.169          8
# 34                SVR  0.705  1.120516e+07  2.974377e+07    18.790         51
# 35  Linear Regression  0.875  1.011631e+07  1.498995e+07    10.369          6
# 36  Linear Regression  0.931  5.872774e+07  7.561032e+07    39.004          6
# 37  Linear Regression  0.911  1.060721e+08  1.247282e+08    36.056          5
# 38              Ridge  0.693  8.821408e+05  9.408844e+05     0.632          3
# 39  Linear Regression  1.000  0.000000e+00  0.000000e+00     0.000          2
# 40              Ridge  0.995  1.021210e+06  1.153119e+06     9.334          5
#
#    log_transform
# 0           none
# 1           none
# 2           none
# 3           both
# 4           none
# 5           both
# 6          input
# 7           none
# 8         output
# 9           none
# 10          both
# 11        output
# 12          none
# 13          both
# 14          none
# 15          both
# 16          none
# 17          none
# 18        output
# 19          both
# 20          none
# 21          none
# 22          both
# 23          none
# 24          none
# 25          both
# 26          none
# 27          both
# 28         input
# 29          none
# 30          none
# 31          both
# 32          none
# 33          none
# 34        output
# 35        output
# 36        output
# 37          none
# 38          both
# 39          none
# 40          none

# %%
predictions = mm.predict_fase_III(
    codigo='',
    longitud_km=8.35,
    puentes_vehiculares_und=10,
    puentes_vehiculares_m2=24258.85,
    puentes_peatonales_und=0,
    puentes_peatonales_m2=0,
    tuneles_und=5,
    tuneles_km=0.92,
    alcance='Rehabilitación',
    models=results
)
predictions
# Out:
# {'1 - TRANSPORTE': None,
#  '2.1 - INFORMACIÓN GEOGRÁFICA': np.float64(38270337.10392039),
#  '2.2 - TRAZADO Y DISEÑO GEOMÉTRICO': np.float64(24155713.73626182),
#  '2.3 - SEGURIDAD VIAL': np.float64(18777320.907161202),
#  '2.4 - SISTEMAS INTELIGENTES': None,
#  '5 - TALUDES': np.float64(71829427.67336465),
#  '6 - PAVIMENTO': np.float64(50552263.3647709),
#  '7 - SOCAVACIÓN': np.float64(63413174.207543574),
#  '11 - PREDIAL': np.float64(16639648.579338765),
#  '12 - IMPACTO AMBIENTAL': None,
#  '15 - OTROS - MANEJO DE REDES': None,
#  '16 - DIRECCIÓN Y COORDINACIÓN': np.float64(194518014.8309798),
#  '3 - GEOLOGÍA': np.float64(33210192.812050264),
#  '4 - SUELOS': np.float64(137199890.22928584),
#  '8 - ESTRUCTURAS': np.float64(581862872.6128875),
#  '9 - TÚNELES': np.float64(103346938.82576008),
#  '10 - URBANISMO Y PAISAJISMO': None,
#  '13 - CANTIDADES': None}

# %%
fase='II'
mm_fase_II = ModelsManagement(fase)
df_vp_fase_II = mm_fase_II.prepare_data()
results_fase_II, summary_df_fase_II = mm_fase_II.train_models()
summary_df_fase_II
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[132], line 4
#       2 mm_fase_II = ModelsManagement(fase)
#       3 df_vp_fase_II = mm_fase_II.prepare_data()
# ----> 4 results_fase_II, summary_df_fase_II = mm_fase_II.train_models()
#       5 summary_df_fase_II
#
# File c:\Code\Road-Project-Prediction\backend\app\services\models_management.py:60, in ModelsManagement.train_models(self)
#      58 def train_models(self) -> tuple[dict, pd.DataFrame]:
#      59     if self.fase == 'II':
# ---> 60         return self.train_models_fase_II()
#      61     elif self.fase == 'III':
#      62         return self.train_models_fase_III()
#
# File c:\Code\Road-Project-Prediction\backend\app\services\models_management.py:77, in ModelsManagement.train_models_fase_II(self)
#      75 results = {}
#      76 for target in targets:
# ---> 77     linear_depedent_results = ml_utils.train_models_by_alcance_and_transform(self.df_vp, predictors, target, hue_name, min_samples=3)
#      78     # linear_depedent_results = train_direction_model(self.df_vp, predictors, target, 'ALCANCE')
#      79     results[target] = ml_utils.consolidate_results_by_alcance(linear_depedent_results)
#
# File c:\Code\Road-Project-Prediction\backend\app\utils\ml_utils.py:753, in train_models_by_alcance_and_transform(df_vp, predictors, target, hue_name, min_samples)
#     746 def print_prediction_metrics(results: pd.DataFrame, target_name: str) -> pd.DataFrame:
#     747     """
#     748     Print comprehensive prediction accuracy metrics from a results DataFrame.
#     749
#     750     Parameters:
#     751     -----------
#     752     results : pd.DataFrame
# --> 753         DataFrame containing 'ACTUAL' and 'PREDICTED' columns with the true and predicted values
#     754     target_name : str
#     755         Name of the target variable being predicted (for display purposes)
#     756
#     757     Returns:
#     758     --------
#     759     pd.DataFrame
#     760         Enhanced results DataFrame with additional metrics:
#     761         - APE (%): Absolute Percentage Error for each prediction
#     762         - ACCURACY (%): Accuracy percentage (100 - APE)
#     763         - WITHIN_20%: Boolean flag for predictions within ±20% accuracy
#     764     """
#     765     # Validate input DataFrame has required columns
#     766     if 'ACTUAL' not in results.columns or 'PREDICTED' not in results.columns:
#
# File c:\Code\Road-Project-Prediction\backend\app\utils\ml_utils.py:66, in train_multiple_models(df_vp, predictors, target, log_transform, apply_outlier_removal)
#      63 numerical_cols = df_nonzero.select_dtypes(include=[np.number]).columns.tolist()
#      65 # Scale features for better outlier detection
# ---> 66 scaler = StandardScaler()
#      67 X_scaled = scaler.fit_transform(df_nonzero[numerical_cols])
#      69 # Initialize outlier flags
#
# File c:\Users\forer\anaconda3\envs\practicum\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\forer\anaconda3\envs\practicum\Lib\site-packages\sklearn\pipeline.py:663, in Pipeline.fit(self, X, y, **params)
#     657     if self._final_estimator != "passthrough":
#     658         last_step_params = self._get_metadata_for_step(
#     659             step_idx=len(self) - 1,
#     660             step_params=routed_params[self.steps[-1][0]],
#     661             all_params=params,
#     662         )
# --> 663         self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#     665 return self
#
# File c:\Users\forer\anaconda3\envs\practicum\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\forer\anaconda3\envs\practicum\Lib\site-packages\sklearn\gaussian_process\_gpr.py:311, in GaussianProcessRegressor.fit(self, X, y)
#     306         return -self.log_marginal_likelihood(theta, clone_kernel=False)
#     308 # First optimize starting from theta specified in kernel
#     309 optima = [
#     310     (
# --> 311         self._constrained_optimization(
#     312             obj_func, self.kernel_.theta, self.kernel_.bounds
#     313         )
#     314     )
#     315 ]
#     317 # Additional runs are performed from log-uniform chosen initial
#     318 # theta
#     319 if self.n_restarts_optimizer > 0:
#
# File c:\Users\forer\anaconda3\envs\practicum\Lib\site-packages\sklearn\gaussian_process\_gpr.py:656, in GaussianProcessRegressor._constrained_optimization(self, obj_func, initial_theta, bounds)
#     654 def _constrained_optimization(self, obj_func, initial_theta, bounds):
#     655     if self.optimizer == "fmin_l_bfgs_b":
# --> 656         opt_res = scipy.optimize.minimize(
#     657             obj_func,
#     658             initial_theta,
#     659             method="L-BFGS-B",
#     660             jac=True,
#     661             bounds=bounds,
#     662         )
#     663         _check_optimize_result("lbfgs", opt_res)
#     664         theta_opt, func_min = opt_res.x, opt_res.fun
#
# File c:\Users\forer\anaconda3\envs\practicum\Lib\site-packages\scipy\optimize\_minimize.py:784, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     781     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     782                              **options)
#     783 elif meth == 'l-bfgs-b':
# --> 784     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     785                            callback=callback, **options)
#     786 elif meth == 'tnc':
#     787     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     788                         **options)
#
# File c:\Users\forer\anaconda3\envs\practicum\Lib\site-packages\scipy\optimize\_lbfgsb_py.py:413, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, workers, **unknown_options)
#     410     x0 = np.clip(x0, bounds[0], bounds[1])
#     412 # _prepare_scalar_function can use bounds=None to represent no bounds
# --> 413 sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#     414                               bounds=bounds,
#     415                               finite_diff_rel_step=finite_diff_rel_step,
#     416                               workers=workers)
#     418 func_and_grad = sf.fun_and_grad
#     420 nbd = zeros(n, np.int32)
#
# File c:\Users\forer\anaconda3\envs\practicum\Lib\site-packages\scipy\optimize\_optimize.py:310, in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess, workers)
#     306 workers = workers or map
#     308 # ScalarFunction caches. Reuse of fun(x) during grad
#     309 # calculation reduces overall function evaluations.
# --> 310 sf = ScalarFunction(fun, x0, args, grad, hess,
#     311                     finite_diff_rel_step, bounds, epsilon=epsilon,
#     312                     workers=workers)
#     314 return sf
#
# File c:\Users\forer\anaconda3\envs\practicum\Lib\site-packages\scipy\optimize\_differentiable_functions.py:274, in ScalarFunction.__init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon, workers)
#     272 # Initial function evaluation
#     273 self._nfev = 0
# --> 274 self._update_fun()
#     276 # Initial gradient evaluation
#     277 self._wrapped_grad = _ScalarGradWrapper(
#     278     grad,
#     279     fun=self._wrapped_fun,
#     280     args=args,
#     281     finite_diff_options=finite_diff_options,
#     282 )
#
# File c:\Users\forer\anaconda3\envs\practicum\Lib\site-packages\scipy\optimize\_differentiable_functions.py:353, in ScalarFunction._update_fun(self)
#     351 def _update_fun(self):
#     352     if not self.f_updated:
# --> 353         fx = self._wrapped_fun(self.x)
#     354         self._nfev += 1
#     355         if fx < self._lowest_f:
#
# File c:\Users\forer\anaconda3\envs\practicum\Lib\site-packages\scipy\_lib\_util.py:590, in _ScalarFunctionWrapper.__call__(self, x)
#     587 def __call__(self, x):
#     588     # Send a copy because the user may overwrite it.
#     589     # The user of this class might want `x` to remain unchanged.
# --> 590     fx = self.f(np.copy(x), *self.args)
#     591     self.nfev += 1
#     593     # Make sure the function returns a true scalar
#
# File c:\Users\forer\anaconda3\envs\practicum\Lib\site-packages\scipy\optimize\_optimize.py:80, in MemoizeJac.__call__(self, x, *args)
#      78 def __call__(self, x, *args):
#      79     """ returns the function value """
# ---> 80     self._compute_if_needed(x, *args)
#      81     return self._value
#
# File c:\Users\forer\anaconda3\envs\practicum\Lib\site-packages\scipy\optimize\_optimize.py:74, in MemoizeJac._compute_if_needed(self, x, *args)
#      72 if not np.all(x == self.x) or self._value is None or self.jac is None:
#      73     self.x = np.asarray(x).copy()
# ---> 74     fg = self.fun(x, *args)
#      75     self.jac = fg[1]
#      76     self._value = fg[0]
#
# File c:\Users\forer\anaconda3\envs\practicum\Lib\site-packages\sklearn\gaussian_process\_gpr.py:301, in GaussianProcessRegressor.fit.<locals>.obj_func(theta, eval_gradient)
#     299 def obj_func(theta, eval_gradient=True):
#     300     if eval_gradient:
# --> 301         lml, grad = self.log_marginal_likelihood(
#     302             theta, eval_gradient=True, clone_kernel=False
#     303         )
#     304         return -lml, -grad
#     305     else:
#
# File c:\Users\forer\anaconda3\envs\practicum\Lib\site-packages\sklearn\gaussian_process\_gpr.py:587, in GaussianProcessRegressor.log_marginal_likelihood(self, theta, eval_gradient, clone_kernel)
#     585 K[np.diag_indices_from(K)] += self.alpha
#     586 try:
# --> 587     L = cholesky(K, lower=GPR_CHOLESKY_LOWER, check_finite=False)
#     588 except np.linalg.LinAlgError:
#     589     return (-np.inf, np.zeros_like(theta)) if eval_gradient else -np.inf
#
# File c:\Users\forer\anaconda3\envs\practicum\Lib\site-packages\scipy\_lib\_util.py:1203, in _apply_over_batch.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#    1202 def decorator(f):
# -> 1203     @functools.wraps(f)
#    1204     def wrapper(*args, **kwargs):
#    1205         args = list(args)
#    1207         # Ensure all arrays in `arrays`, other arguments in `other_args`/`kwargs`
#
# KeyboardInterrupt:

# %%
target_suelos = '4 - SUELOS'
df_clean = df_vp[(df_vp[target_suelos] > 0) & (((df_vp['PUENTES VEHICULARES UND'] > 0) & (df_vp['PUENTES VEHICULARES M2'] > 0)) | (df_vp['PUENTES PEATONALES UND'] > 0))]

df_grouped = get_bridges_structures_tunnels(df_clean, target_suelos)
df_grouped
# Out:
#     CÓDIGO          ALCANCE    4 - SUELOS  LONGITUD KM  \
# 0     0001  Segunda calzada  1.878437e+08       17.400
# 1  0266702     Mejoramiento  1.326106e+07        5.000
# 2  0300605  Segunda calzada  1.308015e+08       17.000
# 3  0347801   Rehabilitación  5.740222e+08       16.850
# 4  0552903     Mejoramiento  6.696069e+07       10.060
# 5  0581301     Mejoramiento  4.285348e+07        5.243
# 6  0654801            Nuevo  1.470113e+08       69.310
# 7     6935  Segunda calzada  1.029912e+08       37.960
#
#    PUENTES VEHICULARES UND  PUENTES VEHICULARES M2  PUENTES PEATONALES UND  \
# 0                       11                    4856                      14
# 1                        0                       0                       1
# 2                       13                   16654                       0
# 3                       26                   51069                       0
# 4                        6                    3837                       0
# 5                        2                      38                       0
# 6                        7                       0                      10
# 7                        4                    6292                       1
#
#    PUENTES PEATONALES M2  TUNELES UND  TUNELES KM
# 0                   1365            0      0.0000
# 1                     58            0      0.0000
# 2                      0            0      0.0000
# 3                      0           20      3.1947
# 4                      0            0      0.0000
# 5                      0            3      0.1460
# 6                      0            1      0.0000
# 7                     77            0      0.0000

# %%
predictors_suelos = ['PUENTES VEHICULARES UND', 'PUENTES VEHICULARES M2']
df_clean = ml_utils.remove_outliers(df_grouped, target_suelos)
ml_utils.train_multiple_models(df_clean, predictors_suelos, target_suelos, log_transform='both')
# train_brindges_structures_model(df_grouped, target_suelos, predictors_suelos, use_log_transform=True)
# Out:
# (array([[ 2.48490665,  8.48817624],
#         [ 0.        ,  0.        ],
#         [ 2.63905733,  9.72046575],
#         [ 3.29583687, 10.84095252],
#         [ 1.94591015,  8.25270668],
#         [ 1.09861229,  3.66356165],
#         [ 2.07944154,  0.        ],
#         [ 1.60943791,  8.74719318]]),
#  array([1.87843738e+08, 1.32610640e+07, 1.30801475e+08, 5.74022243e+08,
#         6.69606925e+07, 4.28534818e+07, 1.47011320e+08, 1.02991160e+08]),
#  array([1.76116199e+08, 1.41991054e+07, 2.34803427e+08, 3.36425760e+08,
#         1.08196810e+08, 4.27960570e+07, 8.40274363e+07, 5.64600722e+07]),
#  TransformedTargetRegressor(func=<ufunc 'log1p'>, inverse_func=<ufunc 'expm1'>,
#                             regressor=Pipeline(steps=[('scaler',
#                                                        StandardScaler()),
#                                                       ('model',
#                                                        Ridge(alpha=0.1))])),
#  {'Model': 'Ridge',
#   'R²': 0.659,
#   'MAE': 63134066.208,
#   'RMSE': 96979019.655,
#   'MAPE (%)': 35.495,
#   'Median AE': 43883602.443,
#   'Max Error': 237596482.23})

# %%
fase='III'
mm = ModelsManagement(fase)
df_vp = mm.prepare_data()
results, summary_df = mm.train_models()
summary_df
# Out:
#                                Target                    Alcance  \
# 0        2.1 - INFORMACIÓN GEOGRÁFICA            Segunda calzada
# 1        2.1 - INFORMACIÓN GEOGRÁFICA  operacion y mantenimiento
# 2        2.1 - INFORMACIÓN GEOGRÁFICA             Rehabilitación
# 3   2.2 - TRAZADO Y DISEÑO GEOMÉTRICO            Segunda calzada
# 4   2.2 - TRAZADO Y DISEÑO GEOMÉTRICO  operacion y mantenimiento
# 5   2.2 - TRAZADO Y DISEÑO GEOMÉTRICO               Mejoramiento
# 6   2.2 - TRAZADO Y DISEÑO GEOMÉTRICO             Rehabilitación
# 7   2.2 - TRAZADO Y DISEÑO GEOMÉTRICO             Puesta a punto
# 8                2.3 - SEGURIDAD VIAL            Segunda calzada
# 9                2.3 - SEGURIDAD VIAL  operacion y mantenimiento
# 10               2.3 - SEGURIDAD VIAL               Mejoramiento
# 11               2.3 - SEGURIDAD VIAL             Rehabilitación
# 12               2.3 - SEGURIDAD VIAL             Puesta a punto
# 13        2.4 - SISTEMAS INTELIGENTES            Segunda calzada
# 14        2.4 - SISTEMAS INTELIGENTES  operacion y mantenimiento
# 15        2.4 - SISTEMAS INTELIGENTES               Mejoramiento
# 16        2.4 - SISTEMAS INTELIGENTES             Puesta a punto
# 17                        5 - TALUDES            Segunda calzada
# 18                        5 - TALUDES               Mejoramiento
# 19                        5 - TALUDES             Rehabilitación
# 20                        5 - TALUDES             Puesta a punto
# 21                      6 - PAVIMENTO            Segunda calzada
# 22                      6 - PAVIMENTO             Rehabilitación
# 23                      6 - PAVIMENTO               Mejoramiento
# 24                      6 - PAVIMENTO             Puesta a punto
# 25                     7 - SOCAVACIÓN            Segunda calzada
# 26                     7 - SOCAVACIÓN  operacion y mantenimiento
# 27                     7 - SOCAVACIÓN               Mejoramiento
# 28                     7 - SOCAVACIÓN             Rehabilitación
# 29                     7 - SOCAVACIÓN             Puesta a punto
# 30                       11 - PREDIAL             Rehabilitación
# 31       15 - OTROS - MANEJO DE REDES            Segunda calzada
# 32       15 - OTROS - MANEJO DE REDES  operacion y mantenimiento
# 33       15 - OTROS - MANEJO DE REDES             Puesta a punto
# 34      16 - DIRECCIÓN Y COORDINACIÓN                    General
# 35                       3 - GEOLOGÍA                    General
# 36                         4 - SUELOS                    General
# 37                    8 - ESTRUCTURAS                    General
# 38                        9 - TÚNELES                    General
# 39        10 - URBANISMO Y PAISAJISMO                    General
# 40                    13 - CANTIDADES                    General
#
#                 Model     R²           MAE          RMSE  MAPE (%)  n_samples  \
# 0          ElasticNet  1.000  4.525410e+02  4.795720e+02     0.033          4
# 1          ElasticNet  1.000  3.358601e+03  3.565073e+03     0.163          3
# 2          ElasticNet  1.000  6.105030e+02  7.056370e+02     0.002          3
# 3                 SVR  0.492  9.999063e+05  1.874178e+06    29.641         16
# 4          ElasticNet  1.000  1.542748e+04  1.637573e+04     0.163          3
# 5               Ridge  0.338  4.954865e+06  9.490122e+06    36.907         10
# 6          ElasticNet  1.000  1.599611e+05  1.849783e+05     1.210          5
# 7          ElasticNet  1.000  1.080983e+04  1.358786e+04     0.169          8
# 8    Gaussian Process  0.864  8.529342e+05  1.734885e+06    25.556         17
# 9          ElasticNet  1.000  4.083710e+03  4.334749e+03     0.163          3
# 10         ElasticNet  0.086  4.051322e+06  7.027524e+06    55.761         10
# 11   Gaussian Process  0.900  1.427764e+06  3.036611e+06     4.501          5
# 12         ElasticNet  1.000  1.162009e+04  1.460636e+04     0.169          8
# 13     Bayesian Ridge  0.804  8.510775e+05  2.213944e+06     9.774         14
# 14         ElasticNet  1.000  1.701791e+04  1.806392e+04     0.163          3
# 15   Gaussian Process  1.000  2.098659e+04  5.837328e+04     0.068          8
# 16         ElasticNet  1.000  2.951602e+03  3.710140e+03     0.169          8
# 17              Ridge  0.999  3.781956e+04  6.636421e+04     0.698         12
# 18                SVR -0.259  7.964885e+06  1.377018e+07    56.895         11
# 19                SVR  0.374  1.128922e+07  2.051177e+07   117.532          5
# 20         ElasticNet  1.000  1.175027e+04  1.476999e+04     0.169          8
# 21              Ridge  1.000  1.174599e+03  1.407425e+03     0.050         11
# 22                SVR  0.671  5.683338e+06  1.164980e+07   147.217          5
# 23              Ridge -0.932  1.139075e+07  1.396147e+07   359.676          3
# 24         ElasticNet  1.000  5.246661e+03  6.595009e+03     0.169          8
# 25                SVR  0.411  6.089411e+06  8.521560e+06    40.552         18
# 26         ElasticNet  1.000  3.126238e+04  3.318388e+04     0.163          3
# 27              Ridge  0.688  5.254128e+06  8.647980e+06    34.804         10
# 28         ElasticNet  0.673  9.775898e+06  1.219700e+07    34.051          5
# 29         ElasticNet  1.000  2.454416e+04  3.085180e+04     0.169          8
# 30         ElasticNet  1.000  2.654530e+02  3.068190e+02     0.002          3
# 31                SVR  0.432  1.415328e+06  2.856360e+06    19.236         15
# 32         ElasticNet  1.000  1.720637e+04  1.826396e+04     0.163          3
# 33         ElasticNet  1.000  1.667318e+04  2.095804e+04     0.169          8
# 34                SVR  0.705  1.120516e+07  2.974377e+07    18.790         51
# 35  Linear Regression  0.875  1.011631e+07  1.498995e+07    10.369          6
# 36              Ridge  0.659  6.313407e+07  9.697902e+07    35.495          8
# 37  Linear Regression  0.918  8.899873e+07  1.095391e+08    29.363          6
# 38              Ridge  0.693  8.821408e+05  9.408844e+05     0.632          3
# 39  Linear Regression  1.000  0.000000e+00  0.000000e+00     0.000          2
# 40              Ridge  0.995  1.021210e+06  1.153119e+06     9.334          5
#
#    log_transform
# 0           none
# 1           none
# 2           none
# 3           both
# 4           none
# 5           both
# 6          input
# 7           none
# 8         output
# 9           none
# 10          both
# 11        output
# 12          none
# 13          both
# 14          none
# 15          both
# 16          none
# 17          none
# 18        output
# 19          both
# 20          none
# 21          none
# 22          both
# 23          none
# 24          none
# 25          both
# 26          none
# 27          both
# 28         input
# 29          none
# 30          none
# 31          both
# 32          none
# 33          none
# 34        output
# 35        output
# 36          both
# 37          none
# 38          both
# 39          none
# 40          none
