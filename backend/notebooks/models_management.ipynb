# %%
import pandas as pd
import os
import sys
import warnings

warnings.filterwarnings('ignore')

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.insert(0, project_root)

import app.services.models_management as models_management
import app.utils.ml_utils as ml_utils


# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
fase='III'
mm = models_management.ModelsManagement(fase)
df_vp = mm.prepare_data()
results, summary_df = mm.train_models()
summary_df
# Out:
#                                Target                    Alcance  \
# 0        2.1 - INFORMACIÓN GEOGRÁFICA            Segunda calzada
# 1        2.1 - INFORMACIÓN GEOGRÁFICA  operacion y mantenimiento
# 2        2.1 - INFORMACIÓN GEOGRÁFICA             Rehabilitación
# 3   2.2 - TRAZADO Y DISEÑO GEOMÉTRICO            Segunda calzada
# 4   2.2 - TRAZADO Y DISEÑO GEOMÉTRICO  operacion y mantenimiento
# 5   2.2 - TRAZADO Y DISEÑO GEOMÉTRICO               Mejoramiento
# 6   2.2 - TRAZADO Y DISEÑO GEOMÉTRICO             Rehabilitación
# 7   2.2 - TRAZADO Y DISEÑO GEOMÉTRICO             Puesta a punto
# 8                2.3 - SEGURIDAD VIAL            Segunda calzada
# 9                2.3 - SEGURIDAD VIAL  operacion y mantenimiento
# 10               2.3 - SEGURIDAD VIAL               Mejoramiento
# 11               2.3 - SEGURIDAD VIAL             Rehabilitación
# 12               2.3 - SEGURIDAD VIAL             Puesta a punto
# ...

# %%
predictions = mm.predict_fase_III(
    codigo='',
    longitud_km=12,
    puentes_vehiculares_und=4,
    puentes_vehiculares_m2=6292,
    puentes_peatonales_und=10,
    puentes_peatonales_m2=0,
    tuneles_und=0,
    tuneles_km=0,
    alcance='Segunda calzada',
    models=results
)
# Out:
# Processing 1 - TRANSPORTE...
#   ✗ Target not found in models
# Processing 2.1 - INFORMACIÓN GEOGRÁFICA...
#   ✓ Predicted: 1,598,831.85 (log_transform: none)
# Processing 2.2 - TRAZADO Y DISEÑO GEOMÉTRICO...
#   ✓ Predicted: 7,271,043.19 (log_transform: both)
# Processing 2.3 - SEGURIDAD VIAL...
#   ✓ Predicted: 33,228,625.25 (log_transform: output)
# Processing 2.4 - SISTEMAS INTELIGENTES...
#   ✓ Predicted: 9,172,427.09 (log_transform: both)
# Processing 5 - TALUDES...
#   ✓ Predicted: 30,430,118.16 (log_transform: none)
# Processing 6 - PAVIMENTO...
#   ✓ Predicted: 13,601,533.43 (log_transform: none)
# Processing 7 - SOCAVACIÓN...
#   ✓ Predicted: 20,756,169.28 (log_transform: both)
# Processing 11 - PREDIAL...
#   ✗ Target not found in models
# Processing 12 - IMPACTO AMBIENTAL...
#   ✗ Target not found in models
# Processing 15 - OTROS - MANEJO DE REDES...
#   ✓ Predicted: 8,018,946.00 (log_transform: both)
# np.float64(1598831.852896621)

# %%
linear_dependency = ['1 - TRANSPORTE', '2.1 - INFORMACIÓN GEOGRÁFICA','2.2 - TRAZADO Y DISEÑO GEOMÉTRICO', 
                '2.3 - SEGURIDAD VIAL', '2.4 - SISTEMAS INTELIGENTES', '5 - TALUDES', '6 - PAVIMENTO',
                '7 - SOCAVACIÓN', '11 - PREDIAL', '12 - IMPACTO AMBIENTAL', '15 - OTROS - MANEJO DE REDES']

# %%
target = '5 - TALUDES'
df = df_vp[df_vp[target] > 0]
predictor = 'LONGITUD KM'
hue = 'ALCANCE'
ml_utils.create_scatter_plot_with_regression(df_vp, predictor, target, hue)

# %%
result = results[target]
X = result['X']
y = result['y']
y_predicted = result['y_predicted']
metrics = result['metrics']

output=X.copy()
output['y_predicted'] = y_predicted

ml_utils.predicted_plot(y, y_predicted, X, predictor, target, hue, df_vp)

# %%
target = '5 - TALUDES'
result = results[target]
result['metrics']
# Out:
#            ALCANCE       Model     R²           MAE          RMSE  MAPE (%)  \
# 0  Segunda calzada       Ridge  0.999  3.781956e+04  6.636421e+04     0.698
# 1     Mejoramiento         SVR -0.259  7.964885e+06  1.377018e+07    56.895
# 2   Rehabilitación         SVR  0.374  1.128922e+07  2.051177e+07   117.532
# 3   Puesta a punto  ElasticNet  1.000  1.175027e+04  1.476999e+04     0.169
#
#      Median AE     Max Error log_transform  n_samples
# 0    20430.699  2.154093e+05          none         12
# 1  2870767.010  3.811364e+07        output         11
# 2  1233617.654  4.473255e+07          both          5
# 3     8454.680  2.925059e+04          none          8

# %%
predictors = ['2.2 - TRAZADO Y DISEÑO GEOMÉTRICO', '7 - SOCAVACIÓN']
hue_name = 'ALCANCE'
df = ml_utils.remove_outliers(df_vp, target)
result_taludes = ml_utils.train_models_by_alcance_and_transform(df, predictors, target, hue_name, min_samples=3)
# Out:
#   → Removed 5/44 outliers (11.4%) using ensemble
#
# ⚠️  Nuevo: Insufficient data (2 samples) - Skipped
#   → Removed 0/11 outliers (0.0%) using ensemble
#
# ...
# Training: Mejoramiento | Log Transform: none
# ...
#
# ...
# RESULTS - 5 - TALUDES
# Predictors: 2.2 - TRAZADO Y DISEÑO GEOMÉTRICO + 7 - SOCAVACIÓN
# Log Transform: none
# ...
#
#            Model     R²          MAE         RMSE  MAPE (%)   Median AE    Max Error
#   Bayesian Ridge -0.210 10750339.698 13498367.487   136.552 9195929.211 35022319.494
#              SVR -0.250  8166664.822 13719846.689    61.273 3300474.346 37807885.593
#       ElasticNet -0.531 12110688.811 15181627.462   137.711 8640598.907 35692179.993
#            Ridge -0.546 12109351.561 15260069.314   137.251 8662234.306 35582718.994
# Gaussian Process -1.027 12438175.254 17472596.046   100.000 6931840.500 44276647.521
#
# ...
#
# ✓ Best Model Selected: Bayesian Ridge
#   R² = -0.210, MAPE = 136.55%
#
#
# ...
# Training: Mejoramiento | Log Transform: input
# ...
#
# ...
# RESULTS - 5 - TALUDES
# ...

# %%
result_taludes['Mejoramiento']
# Out:
# {'X': array([[ 5.  ],
#         [50.9 ],
#         [ 9.  ],
#         [21.  ],
#         [14.  ],
#         [ 6.56],
#         [18.92],
#         [14.52],
#         [ 9.86],
#         [ 5.  ],
#         [10.06]]),
#  'y': array([25736595.39018761, 21052981.34198505,  3722531.08207987,
#          8685905.85818637,  5790603.90545758,  2713311.54427155,
#          7825587.56366124,  6005683.47908886,  4078239.60770084,
#          6931840.50038631, 44276647.52087125]),
#  'y_predicted': array([6272188.56693396, 6593598.53438214, 7012657.70217905,
#         7073073.29967431, 6887612.98686179, 7254032.18341587,
#         6959643.98028175, 6908897.81202966, 6949006.61742223,
#         6536151.27126154, 6163004.52789582]),
#  'model': Pipeline(steps=[('scaler', StandardScaler()),
#                  ('model', SVR(C=0.1, gamma='auto'))]),
#  'metrics': {'Model': 'SVR',
#   'R²': -0.259,
#   'MAE': 7964885.062,
#   'RMSE': 13770184.949,
#   'MAPE (%)': 56.895,
#   'Median AE': 2870767.01,
# ...

# %%
df_test =df_vp[df_vp[target] > 0].loc[:, ['LONGITUD KM', 'ALCANCE', target]]
df_test[df_test['ALCANCE'] == 'Mejoramiento']
# Out:
#     LONGITUD KM       ALCANCE   5 - TALUDES
# 9         5.000  Mejoramiento  2.573660e+07
# 12       50.900  Mejoramiento  2.105298e+07
# 13        9.000  Mejoramiento  3.722531e+06
# 14       21.000  Mejoramiento  8.685906e+06
# 15       14.000  Mejoramiento  5.790604e+06
# 16        6.560  Mejoramiento  2.713312e+06
# 17       18.920  Mejoramiento  7.825588e+06
# 18       14.520  Mejoramiento  6.005683e+06
# 19        9.860  Mejoramiento  4.078240e+06
# 23        5.000  Mejoramiento  6.931841e+06
# 24       10.060  Mejoramiento  4.427665e+07
# 25        5.243  Mejoramiento  6.485859e+07

# %%
results['13 - CANTIDADES']
# Out:
# {'X': array([[  11, 4856,   14],
#         [   0,    0,    0],
#         [   6, 3837,    0],
#         [   2,   38,    0],
#         [   9,    0,   10]]),
#  'y': array([13772380.32281169,  6853860.45150146,  3513204.09028635,
#         17256944.97143232, 47799189.09531402]),
#  'y_predicted': array([14463857.70480844,  8430342.03289168,  3131927.36716329,
#         16539238.83129523, 46060078.81777594]),
#  'model': Pipeline(steps=[('scaler', StandardScaler()), ('model', Ridge(alpha=0.01))]),
#  'metrics': {'Model': 'Ridge',
#   'R²': 0.995,
#   'MAE': 1021210.421,
#   'RMSE': 1153118.706,
#   'MAPE (%)': 9.334,
#   'Median AE': 717706.14,
#   'Max Error': 1739110.278}}
